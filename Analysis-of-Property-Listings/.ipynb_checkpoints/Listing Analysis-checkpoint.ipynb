# %%
import numpy as np
import pandas as pd #Construct dataframes
from tqdm import tqdm #Progress Bar
import re #Regular expression matching to help with data cleaning

#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette("rainbow")
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#Import all the Housing data
phoenixhomes = pd.read_csv('csv_files/phoenixhomes.csv')
fortworthhomes = pd.read_csv('csv_files/fortworth.csv')
austinhomes = pd.read_csv('csv_files/austinhomes.csv')
portlandhomes = pd.read_csv('csv_files/portland.csv')
atlantahomes = pd.read_csv('csv_files/atlantahomes.csv')
raw = pd.concat([atlantahomes, austinhomes, fortworthhomes, phoenixhomes, portlandhomes])
raw.head()
# Out:
# C:\Users\JChaotogo\Anaconda\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
#    Unnamed: 0 address              apprec baths beds     city  \
# 0         NaN     NaN  $173,134 (+12.8 %)   3.0  3.0  atlanta
# 1         NaN     NaN   $247,838 (+6.9 %)   3.0  5.0  atlanta
# 2         NaN     NaN    +$8,264 (+3.1 %)   NaN  NaN  atlanta
# 3         NaN     NaN   $200,428 (+6.5 %)   3.0  4.0  atlanta
# 4         NaN     NaN   $362,880 (+3.4 %)   5.0  5.0  atlanta
#
#                              hoa                      rent saleprice  sqft  \
# 0                             []  ['"rentZestimate":1250']    159900  1800
# 1  ['HOA Fee","factValue":"$33']  ['"rentZestimate":1911']    234900  3087
# 2                             []  ['"rentZestimate":1895']    263900   NaN
# 3  ['HOA Fee","factValue":"$16']  ['"rentZestimate":1500']    187000  2056
# 4                             []  ['"rentZestimate":2195']    285900  3946
#
#                              tax  \
# 0    2017 $679 +29.7% $16,560 --
# 1  2017 $1,494 +18.8% $51,760 --
# 2                            NaN
# 3    2017 $997 +10.8% $48,040 --
# 4  2017 $2,978 +37.2% $78,920 --
#
#                                                 type  \
# 0                                      single family
# 1                                      single family
# 2  hours: monday- thursday: 11am-6pm, friday by a...
# 3                                      single family
# 4                                      single family
#
#                                                  url    year  \
# 0  https://www.zillow.com/homedetails/2152-Maxwel...  1980.0
# 1  https://www.zillow.com/homedetails/2431-Gilber...  2005.0
# 2  https://www.zillow.com/community/cambridge-mea...     NaN
# 3  https://www.zillow.com/homedetails/4900-Promen...  1996.0
# 4  https://www.zillow.com/homedetails/290-Sheffie...  2001.0
#
#                 zestimate    zip
# 0  ['"zestimate":153542']  30311
# 1  ['"zestimate":231819']  30331
# 2  ['"zestimate":275203']  30331
# 3  ['"zestimate":188107']  30331
# 4  ['"zestimate":350914']  30331

# %%
#Clean up data
raw.tax = raw.tax.fillna('0\$0\$0')
df = raw.fillna(0)
df.zestimate = df.zestimate.apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df.rent = df.rent.apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df.hoa = df.hoa.apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df.saleprice = df.saleprice.apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df.zip = df.zip.apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df.year = df.year.astype(int)
df.head()
# Out:
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft                            tax  \
# 0     159900  1800    2017 $679 +29.7% $16,560 --
# 1     234900  3087  2017 $1,494 +18.8% $51,760 --
# 2     263900     0                        0\$0\$0
# 3     187000  2056    2017 $997 +10.8% $48,040 --
# 4     285900  3946  2017 $2,978 +37.2% $78,920 --
#
#                                                 type  \
# 0                                      single family
# 1                                      single family
# 2  hours: monday- thursday: 11am-6pm, friday by a...
# 3                                      single family
# 4                                      single family
#
#                                                  url  year  zestimate    zip
# 0  https://www.zillow.com/homedetails/2152-Maxwel...  1980     153542  30311
# 1  https://www.zillow.com/homedetails/2431-Gilber...  2005     231819  30331
# 2  https://www.zillow.com/community/cambridge-mea...     0     275203  30331
# 3  https://www.zillow.com/homedetails/4900-Promen...  1996     188107  30331
# 4  https://www.zillow.com/homedetails/290-Sheffie...  2001     350914  30331

# %%
#Split up tax information into year, amount, and assessed value and convert it to integers
df.tax = df.tax.str.replace('-', '')
df.tax = df.tax.apply(lambda x: x.strip())
df['taxyear'] = df.tax.apply(lambda x: re.findall('^201[0-9]', str(x))).apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)

tax = df.tax
taxsplit = tax.apply(lambda x: re.split('\$', str(x)))
df['taxamt'] = taxsplit.apply(lambda x: x[1]).apply(lambda x: re.split(' ', str(x))[0]).apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(int)
df['assessedvalue'] = taxsplit.apply(lambda x:x[-1]).apply(lambda x: re.sub('[\+\-]?\d{1,3}\.?\d{0,2}%','', str(x))).apply(lambda x: re.sub('\D', '', str(x))).replace('', 0).astype(np.int64)
apprec = df.apprec.apply(lambda x: re.split(' ', str(x)))
df['appreciation'] = apprec.apply(lambda x:x[-1])
df.head()
# Out:
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft                         tax  \
# 0     159900  1800    2017 $679 +29.7% $16,560
# 1     234900  3087  2017 $1,494 +18.8% $51,760
# 2     263900     0                     0\$0\$0
# 3     187000  2056    2017 $997 +10.8% $48,040
# 4     285900  3946  2017 $2,978 +37.2% $78,920
#
#                                                 type  \
# 0                                      single family
# 1                                      single family
# 2  hours: monday- thursday: 11am-6pm, friday by a...
# 3                                      single family
# 4                                      single family
#
#                                                  url  year  zestimate    zip  \
# 0  https://www.zillow.com/homedetails/2152-Maxwel...  1980     153542  30311
# 1  https://www.zillow.com/homedetails/2431-Gilber...  2005     231819  30331
# 2  https://www.zillow.com/community/cambridge-mea...     0     275203  30331
# 3  https://www.zillow.com/homedetails/4900-Promen...  1996     188107  30331
# 4  https://www.zillow.com/homedetails/290-Sheffie...  2001     350914  30331
#
#    taxyear  taxamt  assessedvalue appreciation
# 0     2017     679          16560    (+12.8 %)
# 1     2017    1494          51760     (+6.9 %)
# 2        0       0              0     (+3.1 %)
# 3     2017     997          48040     (+6.5 %)
# 4     2017    2978          78920     (+3.4 %)

# %%
#Clean up appreciation of symbols and convert to float
df.appreciation = df.appreciation.str.replace('(', '')
df.appreciation = df.appreciation.str.replace(')', '')
df.appreciation = df.appreciation.str.replace('+', '')
df.appreciation = df.appreciation.str.replace('%', '')
df.appreciation = df.appreciation.str.replace('Unavailable', '0')
df.appreciation = df.appreciation.astype(float)/100

# %%
df.head()
# Out:
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft                         tax  \
# 0     159900  1800    2017 $679 +29.7% $16,560
# 1     234900  3087  2017 $1,494 +18.8% $51,760
# 2     263900     0                     0\$0\$0
# 3     187000  2056    2017 $997 +10.8% $48,040
# 4     285900  3946  2017 $2,978 +37.2% $78,920
#
#                                                 type  \
# 0                                      single family
# 1                                      single family
# 2  hours: monday- thursday: 11am-6pm, friday by a...
# 3                                      single family
# 4                                      single family
#
#                                                  url  year  zestimate    zip  \
# 0  https://www.zillow.com/homedetails/2152-Maxwel...  1980     153542  30311
# 1  https://www.zillow.com/homedetails/2431-Gilber...  2005     231819  30331
# 2  https://www.zillow.com/community/cambridge-mea...     0     275203  30331
# 3  https://www.zillow.com/homedetails/4900-Promen...  1996     188107  30331
# 4  https://www.zillow.com/homedetails/290-Sheffie...  2001     350914  30331
#
#    taxyear  taxamt  assessedvalue  appreciation
# 0     2017     679          16560         0.128
# 1     2017    1494          51760         0.069
# 2        0       0              0         0.031
# 3     2017     997          48040         0.065
# 4     2017    2978          78920         0.034

# %%
df['annualrent'] = df.rent*12
df['annualhoa'] = df.hoa*12
df['grossreturnpercent'] = df.annualrent/df.saleprice
df.head()
# Out:
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft         ...          year zestimate    zip  taxyear  \
# 0     159900  1800         ...          1980    153542  30311     2017
# 1     234900  3087         ...          2005    231819  30331     2017
# 2     263900     0         ...             0    275203  30331        0
# 3     187000  2056         ...          1996    188107  30331     2017
# 4     285900  3946         ...          2001    350914  30331     2017
#
#    taxamt  assessedvalue  appreciation  annualrent  annualhoa  \
# 0     679          16560         0.128       15000          0
# 1    1494          51760         0.069       22932        396
# 2       0              0         0.031       22740          0
# 3     997          48040         0.065       18000        192
# 4    2978          78920         0.034       26340          0
#
#    grossreturnpercent
# 0            0.093809
# 1            0.097625
# 2            0.086169
# 3            0.096257
# 4            0.092130
#
# [5 rows x 23 columns]

# %%
#Lets use a rough estimate of .2% of market value as the homeowners insurance rate
df['insurance'] = .002*df.zestimate
df['management'] = .1*df.annualrent
df['vacancy'] = .05*df.annualrent
df['warranty'] = 360 #Warranty for systems runs approx. $30/month
df['repairs'] = 1.5*df.rent

# %%
df['totalcosts'] = df.insurance+df.management+df.vacancy+df.warranty+df.repairs+df.taxamt

# %%
df['netreturn'] = (df.annualrent-df.totalcosts)/df.saleprice
df.head()
# Out:
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft    ...     annualrent annualhoa grossreturnpercent  \
# 0     159900  1800    ...          15000         0           0.093809
# 1     234900  3087    ...          22932       396           0.097625
# 2     263900     0    ...          22740         0           0.086169
# 3     187000  2056    ...          18000       192           0.096257
# 4     285900  3946    ...          26340         0           0.092130
#
#    insurance  management  vacancy  warranty  repairs  totalcosts  netreturn
# 0    307.084      1500.0    750.0       360   1875.0    5471.084   0.059593
# 1    463.638      2293.2   1146.6       360   2866.5    8623.938   0.060911
# 2    550.406      2274.0   1137.0       360   2842.5    7163.906   0.059023
# 3    376.214      1800.0    900.0       360   2250.0    6683.214   0.060518
# 4    701.828      2634.0   1317.0       360   3292.5   11283.328   0.052664
#
# [5 rows x 30 columns]

# %%
#Zipcodes with the highest expected average net returns.
df[(df.netreturn>0)&
   (df.netreturn<1)&
   (df.taxamt>0)].groupby('zip')[['netreturn']].mean().sort_values('netreturn',ascending=False).head(20)
# Out:
#        netreturn
# zip
# 76140   0.126586
# 76040   0.107621
# 76104   0.080802
# 76105   0.076653
# 76119   0.073055
# 76164   0.067195
# 76103   0.064894
# 76112   0.062111
# 76111   0.058663
# 76106   0.058252
# 76102   0.057470
# 30354   0.056220
# 76028   0.056128
# 30331   0.054571
# 85051   0.054466
# 30327   0.052481
# 30307   0.051580
# 30315   0.049729
# 76116   0.049482
# 30303   0.049418

# %%
def plot(metric):
    cities = ['portland', 'austin', 'fort worth', 'atlanta', 'phoenix']
    plt.figure(figsize=(20,10))
    for i, c in enumerate(cities):
        mean = df[(df.city==c)&(df[metric]>0)&(df[metric]<1000000)&(df.zestimate<1000000)&(df.taxamt<10000)][metric].mean()
        std  = df[(df.city==c)&(df[metric]>0)&(df[metric]<1000000)&(df.zestimate<1000000)&(df.taxamt<10000)][metric].std()
        plt.subplot(2,3,i+1)
        sns.distplot(df[(df.city==c)&(df[metric]>0)&(df[metric]<1000000)&(df.taxamt<10000)][metric])
        plt.axvline(mean, color='r', linestyle='--')
        plt.title(f'Distribution of {c} {metric}')
        plt.xlim(mean-(3*std), mean+(3*std))
    plt.show()

# %%
plot('rent')

# %%
plot('saleprice')

# %%
plot('zestimate')

# %%
plot('taxamt')

# %%
#Distribution of home value appreciation by city
plot('appreciation')

# %%
#This shows the expected gross returns from rental income
plot('grossreturnpercent')

# %% [markdown]
# # Taxes
# When calculating how much property tax is due, home values are assessed by the county and a percentage value based on the county is applied to the assessed value. In some markets, assessed value differs wildly from the market price, and in other markets the opposite is true.
#
# Lets look at how tax assessment value differs from the estimated market value of the property.

# %%
cities = ['portland', 'austin', 'fort worth', 'atlanta', 'phoenix']
plt.figure(figsize=(20,10))
for i, c in enumerate(cities):
    plt.subplot(2,3,i+1)
    sns.distplot(df[(df.city==c)&(df['zestimate']>0)&(df['zestimate']<1000000)]['zestimate'], color='blue', label='Estimate', norm_hist=True)
    sns.distplot(df[(df.city==c)&(df['assessedvalue']>0)&(df['assessedvalue']<1000000)]['assessedvalue'], color='red', label='Assessed Value', norm_hist=True)
    plt.xlabel('Dollars')
    city = c.capitalize()
    plt.title(f'{city} Assessed Value Distribution')
    plt.legend()

# %%
df[((df.city=='atlanta')|(df.city=='austin')|
   (df.city=='fort worth')|(df.city=='phoenix')|
   (df.city=='portland'))&(df.taxamt>0)].groupby('city')['taxamt'].describe().transpose()
# Out:
# city       atlanta         austin     fort worth      phoenix     portland
# count   309.000000     143.000000     375.000000   226.000000   329.000000
# mean   1553.692557    6367.797203    6740.928000  2031.393805  3944.057751
# std    1063.491322   27228.747478   23136.371682   905.701256  1318.976747
# min      29.000000     617.000000       9.000000   173.000000    45.000000
# 25%     889.000000    3194.500000    2544.000000  1315.750000  3081.000000
# 50%    1280.000000    4219.000000    4166.000000  2022.500000  3766.000000
# 75%    1979.000000    5199.500000    6340.500000  2650.750000  4705.000000
# max    6431.000000  329273.000000  295386.000000  4386.000000  8884.000000

# %% [markdown]
# Fort Worth, on average, assesses home value close to that of the market price while Phoenix has extremely low tax assessments. Texas has the highest tax rate of ~2.1% of assessed value while Phoenix's is only .80%. With home prices continuing to increase, we can expect the 2019 tax assessment to be even higher.

# %% [markdown]
# # Appreciation
# Home values continue to rise despite increasing interest rates, but are expected to level off in the coming years. Below are the expected appreciation percentages for 2019.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'address', 'apprec', 'baths', 'beds', 'city', 'hoa',
#        'rent', 'saleprice', 'sqft', 'tax', 'type', 'url', 'year', 'zestimate',
#        'zip', 'taxyear', 'taxamt', 'assessedvalue', 'appreciation',
#        'annualrent', 'annualhoa', 'grossreturnpercent', 'insurance',
#        'management', 'vacancy', 'warranty', 'repairs', 'totalcosts',
#        'netreturn'],
#       dtype='object')

# %%
dfmetro = df[df.city.isin(cities)]
dfmetro['apprec_plus_netreturn'] = (dfmetro.appreciation)+dfmetro.netreturn
dfmetro.head()
# Out:
# C:\Users\JChaotogo\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0 address              apprec baths beds     city  hoa  rent  \
# 0         0.0       0  $173,134 (+12.8 %)   3.0  3.0  atlanta    0  1250
# 1         0.0       0   $247,838 (+6.9 %)   3.0  5.0  atlanta   33  1911
# 2         0.0       0    +$8,264 (+3.1 %)     0    0  atlanta    0  1895
# 3         0.0       0   $200,428 (+6.5 %)   3.0  4.0  atlanta   16  1500
# 4         0.0       0   $362,880 (+3.4 %)   5.0  5.0  atlanta    0  2195
#
#    saleprice  sqft          ...           annualhoa grossreturnpercent  \
# 0     159900  1800          ...                   0           0.093809
# 1     234900  3087          ...                 396           0.097625
# 2     263900     0          ...                   0           0.086169
# 3     187000  2056          ...                 192           0.096257
# 4     285900  3946          ...                   0           0.092130
#
#   insurance  management  vacancy  warranty  repairs  totalcosts  netreturn  \
# 0   307.084      1500.0    750.0       360   1875.0    5471.084   0.059593
# 1   463.638      2293.2   1146.6       360   2866.5    8623.938   0.060911
# 2   550.406      2274.0   1137.0       360   2842.5    7163.906   0.059023
# 3   376.214      1800.0    900.0       360   2250.0    6683.214   0.060518
# 4   701.828      2634.0   1317.0       360   3292.5   11283.328   0.052664
#
#    apprec_plus_netreturn
# 0               0.187593
# 1               0.129911
# 2               0.090023
# 3               0.125518
# 4               0.086664
#
# [5 rows x 31 columns]

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='city', y='appreciation', data=dfmetro)
plt.ylim(-20, 30)
plt.ylabel('Percent Appreciation', fontsize=15)
plt.xticks(fontsize=15)
plt.title('Forecasted Appreciation for 2019', fontsize=25)
plt.show()

# %% [markdown]
# # Properties with highest ROI as of 2/11/2019
#
# Estimates are based solely on listing information and costs commonly associated with maintaining property. Some properties may require substantial remodels that may diminish the quality of investment.

# %%
pd.set_option('display.max_colwidth', -1)

dfmetro[(dfmetro.url!=0)&(dfmetro.netreturn<1)&(dfmetro.type=='single family')][['address', 'city', 'zip', 'sqft', 'saleprice', 'netreturn', 'url']].sort_values('netreturn', ascending=False).head(20)
# Out:
#                   address        city    zip  sqft  saleprice  netreturn  \
# 260  0                     fort worth  76110  1256  35000      0.324371
# 252  0                     fort worth  76105  1138  54900      0.179409
# 83   1005 e baltimore ave  fort worth  76104  1232  50000      0.175471
# 54   3109 proctor st       fort worth  76112  1514  68000      0.157927
# 128  1209 e jessamine st   fort worth  76104  2771  60000      0.152807
# 360  0                     fort worth  76103  1120  65000      0.136976
# 129  3849 waldorf st       fort worth  76119  1684  90000      0.118976
# 313  0                     fort worth  76104  819   58500      0.118294
# 69   1133 verbena st       fort worth  76104  1364  79000      0.117978
# 171  1231 bessie st        fort worth  76104  1800  90000      0.109781
# 379  0                     fort worth  76107  1489  105000     0.098803
# 362  0                     fort worth  76105  1068  91000      0.096383
# 177  2518 gould ave        fort worth  76164  996   84900      0.095286
# 299  0                     fort worth  76111  1015  90000      0.095085
# 347  0                     fort worth  76112  932   105000     0.092658
# 486  0                     fort worth  76110  1010  100000     0.092030
# 222  0                     fort worth  76105  1072  89000      0.090663
# 382  0                     fort worth  76104  1107  102000     0.089569
# 38   1357 francis st       fort worth  76164  1697  129900     0.086919
# 120  7845 hood st          fort worth  76135  1795  137900     0.084697
#
#                                                                                             url
# 260  https://www.zillow.com/homedetails/405-W-Bowie-St-Fort-Worth-TX-76110/2124254538_zpid/
# 252  https://www.zillow.com/homedetails/5150-Charlene-St-Fort-Worth-TX-76105/2092455482_zpid/
# 83   https://www.zillow.com/homedetails/1005-E-Baltimore-Ave-Fort-Worth-TX-76104/29110134_zpid/
# 54   https://www.zillow.com/homedetails/3109-Proctor-St-Fort-Worth-TX-76112/29011869_zpid/
# 128  https://www.zillow.com/homedetails/1209-E-Jessamine-St-Fort-Worth-TX-76104/29136302_zpid/
# 360  https://www.zillow.com/homedetails/716-Clairemont-Ave-Fort-Worth-TX-76103/28955653_zpid/
# 129  https://www.zillow.com/homedetails/3849-Waldorf-St-Fort-Worth-TX-76119/28924867_zpid/
# 313  https://www.zillow.com/homedetails/1304-Illinois-Ave-Fort-Worth-TX-76104/28973737_zpid/
# 69   https://www.zillow.com/homedetails/1133-Verbena-St-Fort-Worth-TX-76104/29040381_zpid/
# 171  https://www.zillow.com/homedetails/1231-Bessie-St-Fort-Worth-TX-76104/29133279_zpid/
# 379  https://www.zillow.com/homedetails/5605-Farnsworth-Ave-Fort-Worth-TX-76107/28953981_zpid/
# 362  https://www.zillow.com/homedetails/2663-Burton-Ave-Fort-Worth-TX-76105/29145185_zpid/
# 177  https://www.zillow.com/homedetails/2518-Gould-Ave-Fort-Worth-TX-76164/28974227_zpid/
# 299  https://www.zillow.com/homedetails/2117-Nelson-Ave-Fort-Worth-TX-76111/29114107_zpid/
# 347  https://www.zillow.com/homedetails/7309-Craig-St-Fort-Worth-TX-76112/28969083_zpid/
# 486  https://www.zillow.com/homedetails/1008-E-Shaw-St-Fort-Worth-TX-76110/29038950_zpid/
# 222  https://www.zillow.com/homedetails/1608-Andrew-Ave-Fort-Worth-TX-76105/29007661_zpid/
# 382  https://www.zillow.com/homedetails/944-E-Morningside-Dr-Fort-Worth-TX-76104/29092254_zpid/
# 38   https://www.zillow.com/homedetails/1357-Francis-St-Fort-Worth-TX-76164/29045920_zpid/
# 120  https://www.zillow.com/homedetails/7845-Hood-St-Fort-Worth-TX-76135/29166299_zpid/
